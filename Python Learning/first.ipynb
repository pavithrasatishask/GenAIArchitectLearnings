# %%
a = 3
print(a)
# Out:
# 3

# %%
file = open("notes.txt", "r")
content = file.read()
print(content)  
file.close()
# Out:
# hello, this is a file created for testing purpose

# %%
file = open("notes.txt", "w")
file.write("Hello, this is the modified note\n")
file.close()
file = open("notes.txt", "a")
file.write(" Adding more content.\n")
file.write(" Adding a new content.\n")
file.close()
file = open("notes.txt", "r")
modifiedcontent = file.read() 
print(modifiedcontent)
# Out:
# Hello, this is the modified note
#  Adding more content.
#  Adding a new content.

# %%
with open ("notes.txt", "r") as file:
    finalcontent = file.read()
    print(finalcontent)
# Out:
# Hello, this is the modified note
#  Adding more content.
#  Adding a new content.

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\pavithra.krishnan\OneDrive - FE fundinfo\Desktop\Python Learning
# ['first.ipynb', 'notes.txt']
